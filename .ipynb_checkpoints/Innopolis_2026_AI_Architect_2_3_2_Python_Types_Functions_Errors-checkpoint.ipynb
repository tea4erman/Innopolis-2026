# %% [markdown]
# ### Строки

# %%
grade = 'mark'

# %%
type(grade)
# Out:
# str

# %%
len(grade)
# Out:
# 4

# %%
grade[1]
# Out:
# 'a'

# %%
grade[1:3]
# Out:
# 'ar'

# %%
letter = grade[1]
print(letter)
# Out:
# a

# %%
grade[-1]
# Out:
# 'k'

# %%
grade[len(grade)-1]
# Out:
# 'k'

# %%
s = 'project management'

# %%
s[0:10]
# Out:
# 'project ma'

# %%
s[0:10:3]
# Out:
# 'pjta'

# %%
s[:4]
# Out:
# 'proj'

# %%
s[4:]
# Out:
# 'ect management'

# %%
s[4] = 'E'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s[4] = 'E'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Операции со строками

# %%
grade + " " + s
# Out:
# 'mark project management'

# %%
(grade + " ") * 10
# Out:
# 'mark mark mark mark mark mark mark mark mark mark '

# %%
'roj' in s
# Out:
# True

# %%
'Proj' in s
# Out:
# False

# %%
'proj' in s
# Out:
# True

# %%
grade == 'mark'
# Out:
# True

# %%
'mark' < 'Mark'
# Out:
# False

# %%
'mark' < 'mask'
# Out:
# True

# %%
grade > 'Mark'
# Out:
# True

# %%
grade > ' mark'
# Out:
# True

# %%
grade < 'marк'
# Out:
# True

# %% [markdown]
# ### Методы строк

# %%
s = 'Innopolis'

# %%
s.find('M')

# %%
s.lower()

# %%
s.upper()

# %%
s.find('p')

# %%
s.find('n')

# %%
s.find('ol')

# %%
s.count('n')

# %%
s.count('l')

# %%
name = ' Алексеев Денис Анатольевич '

# %%
name.strip()

# %%
s.startswith('I')

# %%
s.startswith('i')

# %%
s.lower().startswith('i')

# %% [markdown]
# ### f-строки и r-строки

# %%
name = "Денис"

# %%
print('Меня зовут %s' %(name))
print('Меня зовут {}'.format(name))
print(f'Меня зовут {name}')
# Out:
# Меня зовут Денис
# Меня зовут Денис
# Меня зовут Денис

# %%
value_pi = 3.1415926
print('Пи равно %d' %(value_pi))
print('Пи равно %.2f' %(value_pi))
print(f'Пи равно {round(value_pi,4)}')
# Out:
# Пи равно 3
# Пи равно 3.14
# Пи равно 3.1416

# %%
print('Строка \nВторая строка')

print('Строка \tВторая строка')
# Out:
# Строка
# Вторая строка
# Строка 	Вторая строка

# %%
print('Python\nis\easy\to\learn')
print(r'Python\nis\easy\to\learn')
# Out:
# Python
# is\easy	o\learn
# Python\nis\easy\to\learn

# %%
file_path = 'C:\Users\D\Python scripts\Innopolis 2026'
print(file_path)
# Out:
#   Cell In[8], line 1
#     file_path = 'C:\Users\D\Python scripts\Innopolis 2026'
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file_path = 'C:\\Users\\D\\Python scripts\\Innopolis 2026'
print(file_path)
# Out:
# C:\Users\D\Python scripts\Innopolis 2026

# %%
file_path = r'C:\Users\D\Python scripts\Innopolis 2026'
print(file_path)
# Out:
# C:\Users\D\Python scripts\Innopolis 2026

# %% [markdown]
# ### Словари

# %%
enru = {
    'one' : 'один',
    'two' : 'два',
    'three' : 'три'
}

# %%
enru
# Out:
# {'one': 'один', 'two': 'два', 'three': 'три'}

# %%
enru2 = {}

# %%
type(enru2)
# Out:
# dict

# %%
enru2['one'] = 'один'

# %%
enru2
# Out:
# {'one': 'один'}

# %% [markdown]
# ### Поиск по словарям

# %%
enru['two']
# Out:
# 'два'

# %%
enru['four']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 enru['four']
#
# KeyError: 'four'

# %%
len(enru)
# Out:
# 3

# %%
'one' in enru
# Out:
# True

# %%
'one' in enru.keys()
# Out:
# True

# %%
'один' in enru
# Out:
# False

# %%
'один' in enru.values()
# Out:
# True

# %% [markdown]
# ### Методы и функции словарей

# %%
enru.keys()
# Out:
# dict_keys(['one', 'two', 'three'])

# %%
enru.values()
# Out:
# dict_values(['один', 'два', 'три'])

# %%
enru2.clear()

# %%
enru2
# Out:
# {}

# %%
enru['four'] = 'четыре'

# %%
enru
# Out:
# {'one': 'один', 'two': 'два', 'three': 'три', 'four': 'четыре'}

# %%
del enru['three']

# %%
enru
# Out:
# {'one': 'один', 'two': 'два', 'four': 'четыре'}

# %% [markdown]
# ### Операторы ветвления

# %%
x = input('Введите число \n')
x = float(x)
if x > 0:
    print('x - положительное число')
print('Завершение программы')
# Out:
# Введите число
#  -10
# Завершение программы

# %%
x = input('Введите число \n')
x = float(x)
if x % 2 == 0:
    print('x - четное число')
print('Завершение программы')
# Out:
# Введите число
#  15
# Завершение программы

# %%
x = input('Введите число \n')
x = float(x)
if x < 0:
    pass
print('Завершение программы')
# Out:
# Введите число
#  -20
# Завершение программы

# %%
x = input('Введите число \n')
x = float(x)
if x % 2 == 0:
    print('x - четное число')
else:
    print('x - нечетное число')
# Out:
# Введите число
#  0
# x - четное число

# %%
x = input('Введите первое число \n')
x = float(x)
y = input('Введите второе число \n')
y = float(y)

if x > y:
    print('Первое число больше, чем второе')
else:
    if x < y:
        print('Второе число больше, чем первое')
    else:
        print('Первое и второе числа равны')
# Out:
# Введите первое число
#  5
# Введите второе число
#  5
# Первое и второе числа равны

# %%
x = input('Введите первое число \n')
x = float(x)
y = input('Введите второе число \n')
y = float(y)

if x > y:
    print('Первое число больше, чем второе')
elif x < y:
    print('Второе число больше, чем первое')
else:
    print('Первое и второе числа равны')
# Out:
# Введите первое число
#  10
# Введите второе число
#  10
# Первое и второе числа равны

# %%
x = input('Введите первое число \n')
try:
    x = float(x)
    y = input('Введите второе число \n')
    try:
        y = float(y)
        if x > y:
            print('Первое число больше, чем второе')
        elif x < y:
            print('Второе число больше, чем первое')
        else:
            print('Первое и второе числа равны')
    except:
        print('Введите число, а не символы!')
except:
    print('Введите число, а не символы!')
# Out:
# Введите первое число
#  десять
# Введите число, а не символы!

# %%
# Неправильный вариант!

x = input('Введите первое число \n')
try:
    x = float(x)
except:
    print('Введите число, а не символы!')

y = input('Введите второе число \n')
try:
    y = float(y)
except:
    print('Введите число, а не символы!')

if x > y:
    print('Первое число больше, чем второе')
elif x < y:
    print('Второе число больше, чем первое')
else:
    print('Первое и второе числа равны')
# Out:
# Введите первое число
#  десять
# Введите число, а не символы!
# Введите второе число
#  пять
# Введите число, а не символы!
# Второе число больше, чем первое

# %% [markdown]
# ### Составные условия

# %%
x = input('Введите число \n')
x = float(x)

if (x > 0) and (x < 100):
    print("Ввели маленькое число")
elif (x >= 100) and (x < 1000):
    print("Ввели среднее число")
elif (x >= 1000):
    print("Ввели большое число")
else:
    print("Ввели ноль либо отрицательное число")
# Out:
# Введите число
#  150
# Ввели среднее число

# %%
x = input('Введите число \n')
x = float(x)

if (x > 0) & (x < 100):
    print("Ввели маленькое число")
elif (x >= 100) & (x < 1000):
    print("Ввели среднее число")
elif x >= 1000:
    print("Ввели большое число")
else:
    print("Ввели ноль либо отрицательное число")
# Out:
# Введите число
#  2000
# Ввели большое число

# %% [markdown]
# ### Оператор цикла while

# %%
n = 3
while n > 0:
    print(n)
    n = n - 1
print('Start!')
# Out:
# 3
# 2
# 1
# Start!

# %%
import time # Импортируем библиотеку time
n = 3
while n > 0:
    print(n)
    n = n - 1
    time.sleep(3) # Из библиотеки time достаем функцию sleep и задаем аргумент 1
print('Start!')
# Out:
# 3
# 2
# 1
# Start!

# %%
n = 0
rate = 0.12
amount = 100000
while amount < 200000 :
    amount = amount * (1 + rate)
    n += 1 # идентично записи n = n + 1
print('Для удвоения вклада при ставке', rate, 'требуется', n, 'лет')
# Out:
# Для удвоения вклада при ставке 0.12 требуется 7 лет

# %%
while True:
    line = input('> ')
    if line == 'stop':
        break
    print(line)
print('End!')
# Out:
# >  A
# A
# >  B
# B
# >  C
# C
# >  stop
# End!

# %%
while True:
    line = input('> ')
    if line[0] == '#':
        continue
    if line == 'stop':
        break
    print(line)
print('End!')
# Out:
# >  #hashtag
# >  stop
# End!

# %%
print("Составляем список гостей")
print("Для выхода напишите 'стоп'")
guests = []
while True:
    guest = input('> Введите имя гостя:\n')
    if guest.lower() == 'стоп':
        break
    guests.append(guest.capitalize())
print('Список составлен!')
# Out:
# Составляем список гостей
# Для выхода напишите 'стоп'
# > Введите имя гостя:
#  ИВАН
# > Введите имя гостя:
#  петр
# > Введите имя гостя:
#  МАрия
# > Введите имя гостя:
#  ЕЛЕнА
# > Введите имя гостя:
#  Стоп
# Список составлен!

# %%
guests
# Out:
# ['Иван', 'Петр', 'Мария', 'Елена']

# %% [markdown]
# ### Оператор цикла for

# %%
students = ['Иван', 'Петр', 'Мария', 'Елена']
for name in students:
    print(f'Привет, {name}!')
# Out:
# Привет, Иван!
# Привет, Петр!
# Привет, Мария!
# Привет, Елена!

# %%
students = ['Иван', 'Петр', 'Мария', 'Елена']
n = len(students)
for i in range(n):
    print(i, end = ": ")
    print(f'Привет, {students[i]}!')
# Out:
# 0: Привет, Иван!
# 1: Привет, Петр!
# 2: Привет, Мария!
# 3: Привет, Елена!

# %%
students = ['Иван', 'Петр', 'Мария', 'Елена']
n = len(students)
i = 0
while i < n:
    print('Привет,', students[i], '!')
    i += 1
# Out:
# Привет, Иван !
# Привет, Петр !
# Привет, Мария !
# Привет, Елена !

# %%
s = 'Innopolis'
for sym in s:
    print(sym)
# Out:
# I
# n
# n
# o
# p
# o
# l
# i
# s

# %%
enru = {
    'one'    : 'один',
    'two'    : 'два',
    'three'  : 'три'
}

for w in enru.keys():
    print(f"Ключ: {w}, значение: {enru[w]}")
# Out:
# Ключ: one, значение: один
# Ключ: two, значение: два
# Ключ: three, значение: три

# %%
for i in range(10):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
for i in range(1,10):
    for j in range(1,10):
        print(i*j, end ='\t')
    print()
# Out:
# 1	2	3	4	5	6	7	8	9
# 2	4	6	8	10	12	14	16	18
# 3	6	9	12	15	18	21	24	27
# 4	8	12	16	20	24	28	32	36
# 5	10	15	20	25	30	35	40	45
# 6	12	18	24	30	36	42	48	54
# 7	14	21	28	35	42	49	56	63
# 8	16	24	32	40	48	56	64	72
# 9	18	27	36	45	54	63	72	81

# %%
s = 0
for i in range(1, 10, 2):
    s += i
print(s)
# Out:
# 25

# %% [markdown]
# ### Пользовательские функции

# %%
def get_median(numbers_list):
    n = len(numbers_list)
    numbers_list.sort()
    if n % 2 == 0:
        a = int(n/2 - 1)
        b = int(n/2)
        median = (numbers_list[a] + numbers_list[b]) / 2
    else:
        a = int((n - 1)/2 )
        median = numbers_list[a]
    print(f'Медиана равна {median}')

# %%
get_median([10, 10, 10, 15, 20, 25, 30])
# Out:
# Медиана равна 15

# %%
get_median(numbers_list = [10, 10, 15, 20, 25, 30])
# Out:
# Медиана равна 17.5

# %%
def get_mode(numbers_list):

    """
    Эта функция определяет моду для указанного списка чисел

    numbers_list - список чисел, должен иметь тип list

    """

    x = 0
    for number in numbers_list:
        if numbers_list.count(number) > x:
            x = numbers_list.count(number)
            mode = number
    return mode

# %%
get_mode?
# Out:
# Signature: get_mode(numbers_list)
# Docstring:
# Эта функция определяет моду для указанного списка чисел
#
# numbers_list - список чисел, должен иметь тип list
# File:      c:\users\d\appdata\local\temp\ipykernel_2640\3383547857.py
# Type:      function

# %%
x = [10, 10, 15, 15, 15, 20, 25, 30]

a = get_mode(x)
print(a)
# Out:
# 15

# %%
numbers_list = [10, 10, 15, 20, 25, 30]
get_mode(numbers_list = numbers_list)
# Out:
# 10

# %% [markdown]
# ### Лямба-функция

# %%
def compute_square(x):
    return x**2

# %%
compute_square(4)
# Out:
# 16

# %%
compute_square_2 = lambda x : x**2

# %%
type(compute_square_2)
# Out:
# function

# %%
compute_square(10)
# Out:
# 100

# %%
compute_square_2(10)
# Out:
# 100

# %%
exponentiation = lambda x, y: x**y
exponentiation(3, 4)
# Out:
# 81

# %% [markdown]
# ### Магические функции

# %%
# %magic

# %%
# %timeit x = range(100)

# %%
# Сравним скорость расчета моды по двум вариантам
# %%timeit

numbers = [20, 15, 10, 25, 15, 10, 10, 20, 30, 20, 20]

x = 0

for number in set(numbers):
    if numbers.count(number) > x:
        x = numbers.count(number)
        mode = number

# %%
# %%timeit

numbers = [20, 15, 10, 25, 15, 10, 10, 20, 30]

frequencies = {}

for number in set(numbers):
    frequencies[number] = numbers.count(number)

freq_list = list(frequencies.values())
idx_max = freq_list.index(max(freq_list))
mode = list(frequencies.keys())[idx_max]

# %%
mode_time = %timeit -o get_mode(numbers_list)

# %% [markdown]
# ### Кoртежи

# %%
cort1 = (1,2,3)

# %%
type(cort1)
# Out:
# tuple

# %%
cort1[2]
# Out:
# 3

# %%
cort1[2] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 cort1[2] = 4
#
# TypeError: 'tuple' object does not support item assignment

# %%
cort2 = 1,2,3

# %%
cort2
# Out:
# (1, 2, 3)
